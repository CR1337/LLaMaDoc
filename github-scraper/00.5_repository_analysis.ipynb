# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import json
from sklearn.decomposition import PCA
from sklearn.manifold import TSNE

# %%
with open("repositories.json") as file:
    repos = json.load(file)
repos[0]
# Out:
# {'id': 54346799,
#  'node_id': 'MDEwOlJlcG9zaXRvcnk1NDM0Njc5OQ==',
#  'name': 'public-apis',
#  'full_name': 'public-apis/public-apis',
#  'private': False,
#  'owner': {'login': 'public-apis',
#   'id': 51121562,
#   'node_id': 'MDEyOk9yZ2FuaXphdGlvbjUxMTIxNTYy',
#   'avatar_url': 'https://avatars.githubusercontent.com/u/51121562?v=4',
#   'gravatar_id': '',
#   'url': 'https://api.github.com/users/public-apis',
#   'html_url': 'https://github.com/public-apis',
#   'followers_url': 'https://api.github.com/users/public-apis/followers',
#   'following_url': 'https://api.github.com/users/public-apis/following{/other_user}',
#   'gists_url': 'https://api.github.com/users/public-apis/gists{/gist_id}',
#   'starred_url': 'https://api.github.com/users/public-apis/starred{/owner}{/repo}',
#   'subscriptions_url': 'https://api.github.com/users/public-apis/subscriptions',
#   'organizations_url': 'https://api.github.com/users/public-apis/orgs',
#   'repos_url': 'https://api.github.com/users/public-apis/repos',
#   'events_url': 'https://api.github.com/users/public-apis/events{/privacy}',
#   'received_events_url': 'https://api.github.com/users/public-apis/received_events',
#   'type': 'Organization',
#   'site_admin': False},
#  'html_url': 'https://github.com/public-apis/public-apis',
#  'description': 'A collective list of free APIs',
#  'fork': False,
#  'url': 'https://api.github.com/repos/public-apis/public-apis',
#  'forks_url': 'https://api.github.com/repos/public-apis/public-apis/forks',
#  'keys_url': 'https://api.github.com/repos/public-apis/public-apis/keys{/key_id}',
#  'collaborators_url': 'https://api.github.com/repos/public-apis/public-apis/collaborators{/collaborator}',
#  'teams_url': 'https://api.github.com/repos/public-apis/public-apis/teams',
#  'hooks_url': 'https://api.github.com/repos/public-apis/public-apis/hooks',
#  'issue_events_url': 'https://api.github.com/repos/public-apis/public-apis/issues/events{/number}',
#  'events_url': 'https://api.github.com/repos/public-apis/public-apis/events',
#  'assignees_url': 'https://api.github.com/repos/public-apis/public-apis/assignees{/user}',
#  'branches_url': 'https://api.github.com/repos/public-apis/public-apis/branches{/branch}',
#  'tags_url': 'https://api.github.com/repos/public-apis/public-apis/tags',
#  'blobs_url': 'https://api.github.com/repos/public-apis/public-apis/git/blobs{/sha}',
#  'git_tags_url': 'https://api.github.com/repos/public-apis/public-apis/git/tags{/sha}',
#  'git_refs_url': 'https://api.github.com/repos/public-apis/public-apis/git/refs{/sha}',
#  'trees_url': 'https://api.github.com/repos/public-apis/public-apis/git/trees{/sha}',
#  'statuses_url': 'https://api.github.com/repos/public-apis/public-apis/statuses/{sha}',
#  'languages_url': 'https://api.github.com/repos/public-apis/public-apis/languages',
#  'stargazers_url': 'https://api.github.com/repos/public-apis/public-apis/stargazers',
#  'contributors_url': 'https://api.github.com/repos/public-apis/public-apis/contributors',
#  'subscribers_url': 'https://api.github.com/repos/public-apis/public-apis/subscribers',
#  'subscription_url': 'https://api.github.com/repos/public-apis/public-apis/subscription',
#  'commits_url': 'https://api.github.com/repos/public-apis/public-apis/commits{/sha}',
#  'git_commits_url': 'https://api.github.com/repos/public-apis/public-apis/git/commits{/sha}',
#  'comments_url': 'https://api.github.com/repos/public-apis/public-apis/comments{/number}',
#  'issue_comment_url': 'https://api.github.com/repos/public-apis/public-apis/issues/comments{/number}',
#  'contents_url': 'https://api.github.com/repos/public-apis/public-apis/contents/{+path}',
#  'compare_url': 'https://api.github.com/repos/public-apis/public-apis/compare/{base}...{head}',
#  'merges_url': 'https://api.github.com/repos/public-apis/public-apis/merges',
#  'archive_url': 'https://api.github.com/repos/public-apis/public-apis/{archive_format}{/ref}',
#  'downloads_url': 'https://api.github.com/repos/public-apis/public-apis/downloads',
#  'issues_url': 'https://api.github.com/repos/public-apis/public-apis/issues{/number}',
#  'pulls_url': 'https://api.github.com/repos/public-apis/public-apis/pulls{/number}',
#  'milestones_url': 'https://api.github.com/repos/public-apis/public-apis/milestones{/number}',
#  'notifications_url': 'https://api.github.com/repos/public-apis/public-apis/notifications{?since,all,participating}',
#  'labels_url': 'https://api.github.com/repos/public-apis/public-apis/labels{/name}',
#  'releases_url': 'https://api.github.com/repos/public-apis/public-apis/releases{/id}',
#  'deployments_url': 'https://api.github.com/repos/public-apis/public-apis/deployments',
#  'created_at': '2016-03-20T23:49:42Z',
#  'updated_at': '2024-05-14T08:53:59Z',
#  'pushed_at': '2024-05-11T00:14:35Z',
#  'git_url': 'git://github.com/public-apis/public-apis.git',
#  'ssh_url': 'git@github.com:public-apis/public-apis.git',
#  'clone_url': 'https://github.com/public-apis/public-apis.git',
#  'svn_url': 'https://github.com/public-apis/public-apis',
#  'homepage': 'http://public-apis.org',
#  'size': 4997,
#  'stargazers_count': 293444,
#  'watchers_count': 293444,
#  'language': 'Python',
#  'has_issues': True,
#  'has_projects': False,
#  'has_downloads': True,
#  'has_wiki': False,
#  'has_pages': False,
#  'has_discussions': False,
#  'forks_count': 31931,
#  'mirror_url': None,
#  'archived': False,
#  'disabled': False,
#  'open_issues_count': 261,
#  'license': {'key': 'mit',
#   'name': 'MIT License',
#   'spdx_id': 'MIT',
#   'url': 'https://api.github.com/licenses/mit',
#   'node_id': 'MDc6TGljZW5zZTEz'},
#  'allow_forking': True,
#  'is_template': False,
#  'web_commit_signoff_required': False,
#  'topics': ['api',
#   'apis',
#   'dataset',
#   'development',
#   'free',
#   'list',
#   'lists',
#   'open-source',
#   'public',
#   'public-api',
#   'public-apis',
#   'resources',
#   'software'],
#  'visibility': 'public',
#  'forks': 31931,
#  'open_issues': 261,
#  'watchers': 293444,
#  'default_branch': 'master',
#  'permissions': {'admin': False,
#   'maintain': False,
#   'push': False,
#   'triage': False,
#   'pull': True},
#  'score': 1.0,
#  'total_contributors': [{'login': 'matheusfelipeog',
#    'id': 50463866,
#    'node_id': 'MDQ6VXNlcjUwNDYzODY2',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/50463866?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/matheusfelipeog',
#    'html_url': 'https://github.com/matheusfelipeog',
#    'followers_url': 'https://api.github.com/users/matheusfelipeog/followers',
#    'following_url': 'https://api.github.com/users/matheusfelipeog/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/matheusfelipeog/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/matheusfelipeog/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/matheusfelipeog/subscriptions',
#    'organizations_url': 'https://api.github.com/users/matheusfelipeog/orgs',
#    'repos_url': 'https://api.github.com/users/matheusfelipeog/repos',
#    'events_url': 'https://api.github.com/users/matheusfelipeog/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/matheusfelipeog/received_events',
#    'type': 'User',
#    'site_admin': False,
#    'contributions': 826},
#   {'login': 'davemachado',
#    'id': 15134885,
#    'node_id': 'MDQ6VXNlcjE1MTM0ODg1',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/15134885?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/davemachado',
#    'html_url': 'https://github.com/davemachado',
#    'followers_url': 'https://api.github.com/users/davemachado/followers',
#    'following_url': 'https://api.github.com/users/davemachado/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/davemachado/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/davemachado/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/davemachado/subscriptions',
#    'organizations_url': 'https://api.github.com/users/davemachado/orgs',
#    'repos_url': 'https://api.github.com/users/davemachado/repos',
#    'events_url': 'https://api.github.com/users/davemachado/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/davemachado/received_events',
#    'type': 'User',
#    'site_admin': False,
#    'contributions': 683},
#   {'login': 'pawelborkar',
#    'id': 36134699,
#    'node_id': 'MDQ6VXNlcjM2MTM0Njk5',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/36134699?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/pawelborkar',
#    'html_url': 'https://github.com/pawelborkar',
#    'followers_url': 'https://api.github.com/users/pawelborkar/followers',
#    'following_url': 'https://api.github.com/users/pawelborkar/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/pawelborkar/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/pawelborkar/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/pawelborkar/subscriptions',
#    'organizations_url': 'https://api.github.com/users/pawelborkar/orgs',
#    'repos_url': 'https://api.github.com/users/pawelborkar/repos',
#    'events_url': 'https://api.github.com/users/pawelborkar/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/pawelborkar/received_events',
#    'type': 'User',
#    'site_admin': False,
#    'contributions': 150},
#   {'login': 'jbrooksuk',
#    'id': 246103,
#    'node_id': 'MDQ6VXNlcjI0NjEwMw==',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/246103?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/jbrooksuk',
#    'html_url': 'https://github.com/jbrooksuk',
#    'followers_url': 'https://api.github.com/users/jbrooksuk/followers',
#    'following_url': 'https://api.github.com/users/jbrooksuk/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/jbrooksuk/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/jbrooksuk/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/jbrooksuk/subscriptions',
#    'organizations_url': 'https://api.github.com/users/jbrooksuk/orgs',
#    'repos_url': 'https://api.github.com/users/jbrooksuk/repos',
#    'events_url': 'https://api.github.com/users/jbrooksuk/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/jbrooksuk/received_events',
#    'type': 'User',
#    'site_admin': False,
#    'contributions': 135},
#   {'login': 'marekdano',
#    'id': 1914165,
#    'node_id': 'MDQ6VXNlcjE5MTQxNjU=',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/1914165?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/marekdano',
#    'html_url': 'https://github.com/marekdano',
#    'followers_url': 'https://api.github.com/users/marekdano/followers',
#    'following_url': 'https://api.github.com/users/marekdano/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/marekdano/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/marekdano/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/marekdano/subscriptions',
#    'organizations_url': 'https://api.github.com/users/marekdano/orgs',
#    'repos_url': 'https://api.github.com/users/marekdano/repos',
#    'events_url': 'https://api.github.com/users/marekdano/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/marekdano/received_events',
#    'type': 'User',
#    'site_admin': False,
#    'contributions': 133},
#   {'login': 'mikestreety',
#    'id': 354085,
#    'node_id': 'MDQ6VXNlcjM1NDA4NQ==',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/354085?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/mikestreety',
#    'html_url': 'https://github.com/mikestreety',
#    'followers_url': 'https://api.github.com/users/mikestreety/followers',
#    'following_url': 'https://api.github.com/users/mikestreety/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/mikestreety/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/mikestreety/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/mikestreety/subscriptions',
#    'organizations_url': 'https://api.github.com/users/mikestreety/orgs',
#    'repos_url': 'https://api.github.com/users/mikestreety/repos',
#    'events_url': 'https://api.github.com/users/mikestreety/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/mikestreety/received_events',
#    'type': 'User',
#    'site_admin': False,
#    'contributions': 129},
#   {'login': 'toddmotto',
#    'id': 1655968,
#    'node_id': 'MDQ6VXNlcjE2NTU5Njg=',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/1655968?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/toddmotto',
#    'html_url': 'https://github.com/toddmotto',
#    'followers_url': 'https://api.github.com/users/toddmotto/followers',
#    'following_url': 'https://api.github.com/users/toddmotto/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/toddmotto/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/toddmotto/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/toddmotto/subscriptions',
#    'organizations_url': 'https://api.github.com/users/toddmotto/orgs',
#    'repos_url': 'https://api.github.com/users/toddmotto/repos',
#    'events_url': 'https://api.github.com/users/toddmotto/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/toddmotto/received_events',
#    'type': 'User',
#    'site_admin': False,
#    'contributions': 99},
#   {'login': 'yannbertrand',
#    'id': 5855339,
#    'node_id': 'MDQ6VXNlcjU4NTUzMzk=',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/5855339?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/yannbertrand',
#    'html_url': 'https://github.com/yannbertrand',
#    'followers_url': 'https://api.github.com/users/yannbertrand/followers',
#    'following_url': 'https://api.github.com/users/yannbertrand/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/yannbertrand/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/yannbertrand/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/yannbertrand/subscriptions',
#    'organizations_url': 'https://api.github.com/users/yannbertrand/orgs',
#    'repos_url': 'https://api.github.com/users/yannbertrand/repos',
#    'events_url': 'https://api.github.com/users/yannbertrand/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/yannbertrand/received_events',
#    'type': 'User',
#    'site_admin': False,
#    'contributions': 86},
#   {'login': 'wesbos',
#    'id': 176013,
#    'node_id': 'MDQ6VXNlcjE3NjAxMw==',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/176013?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/wesbos',
#    'html_url': 'https://github.com/wesbos',
#    'followers_url': 'https://api.github.com/users/wesbos/followers',
#    'following_url': 'https://api.github.com/users/wesbos/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/wesbos/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/wesbos/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/wesbos/subscriptions',
#    'organizations_url': 'https://api.github.com/users/wesbos/orgs',
#    'repos_url': 'https://api.github.com/users/wesbos/repos',
#    'events_url': 'https://api.github.com/users/wesbos/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/wesbos/received_events',
#    'type': 'User',
#    'site_admin': False,
#    'contributions': 44},
#   {'login': 'olekstomek',
#    'id': 26818304,
#    'node_id': 'MDQ6VXNlcjI2ODE4MzA0',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/26818304?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/olekstomek',
#    'html_url': 'https://github.com/olekstomek',
#    'followers_url': 'https://api.github.com/users/olekstomek/followers',
#    'following_url': 'https://api.github.com/users/olekstomek/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/olekstomek/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/olekstomek/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/olekstomek/subscriptions',
#    'organizations_url': 'https://api.github.com/users/olekstomek/orgs',
#    'repos_url': 'https://api.github.com/users/olekstomek/repos',
#    'events_url': 'https://api.github.com/users/olekstomek/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/olekstomek/received_events',
#    'type': 'User',
#    'site_admin': False,
#    'contributions': 41},
#   {'login': 'apilayer-admin',
#    'id': 75280960,
#    'node_id': 'MDQ6VXNlcjc1MjgwOTYw',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/75280960?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/apilayer-admin',
#    'html_url': 'https://github.com/apilayer-admin',
#    'followers_url': 'https://api.github.com/users/apilayer-admin/followers',
#    'following_url': 'https://api.github.com/users/apilayer-admin/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/apilayer-admin/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/apilayer-admin/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/apilayer-admin/subscriptions',
#    'organizations_url': 'https://api.github.com/users/apilayer-admin/orgs',
#    'repos_url': 'https://api.github.com/users/apilayer-admin/repos',
#    'events_url': 'https://api.github.com/users/apilayer-admin/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/apilayer-admin/received_events',
#    'type': 'User',
#    'site_admin': False,
#    'contributions': 21},
#   {'login': 'Nirzak',
#    'id': 11460645,
#    'node_id': 'MDQ6VXNlcjExNDYwNjQ1',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/11460645?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/Nirzak',
#    'html_url': 'https://github.com/Nirzak',
#    'followers_url': 'https://api.github.com/users/Nirzak/followers',
#    'following_url': 'https://api.github.com/users/Nirzak/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/Nirzak/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/Nirzak/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/Nirzak/subscriptions',
#    'organizations_url': 'https://api.github.com/users/Nirzak/orgs',
#    'repos_url': 'https://api.github.com/users/Nirzak/repos',
#    'events_url': 'https://api.github.com/users/Nirzak/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/Nirzak/received_events',
#    'type': 'User',
#    'site_admin': False,
#    'contributions': 17},
#   {'login': 'marijaninjo',
#    'id': 1524326,
#    'node_id': 'MDQ6VXNlcjE1MjQzMjY=',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/1524326?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/marijaninjo',
#    'html_url': 'https://github.com/marijaninjo',
#    'followers_url': 'https://api.github.com/users/marijaninjo/followers',
#    'following_url': 'https://api.github.com/users/marijaninjo/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/marijaninjo/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/marijaninjo/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/marijaninjo/subscriptions',
#    'organizations_url': 'https://api.github.com/users/marijaninjo/orgs',
#    'repos_url': 'https://api.github.com/users/marijaninjo/repos',
#    'events_url': 'https://api.github.com/users/marijaninjo/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/marijaninjo/received_events',
#    'type': 'User',
#    'site_admin': False,
#    'contributions': 14},
#   {'login': 'HZooly',
#    'id': 7328625,
#    'node_id': 'MDQ6VXNlcjczMjg2MjU=',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/7328625?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/HZooly',
#    'html_url': 'https://github.com/HZooly',
#    'followers_url': 'https://api.github.com/users/HZooly/followers',
#    'following_url': 'https://api.github.com/users/HZooly/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/HZooly/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/HZooly/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/HZooly/subscriptions',
#    'organizations_url': 'https://api.github.com/users/HZooly/orgs',
#    'repos_url': 'https://api.github.com/users/HZooly/repos',
#    'events_url': 'https://api.github.com/users/HZooly/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/HZooly/received_events',
#    'type': 'User',
#    'site_admin': False,
#    'contributions': 14},
#   {'login': 'montogeek',
#    'id': 1002461,
#    'node_id': 'MDQ6VXNlcjEwMDI0NjE=',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/1002461?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/montogeek',
#    'html_url': 'https://github.com/montogeek',
#    'followers_url': 'https://api.github.com/users/montogeek/followers',
#    'following_url': 'https://api.github.com/users/montogeek/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/montogeek/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/montogeek/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/montogeek/subscriptions',
#    'organizations_url': 'https://api.github.com/users/montogeek/orgs',
#    'repos_url': 'https://api.github.com/users/montogeek/repos',
#    'events_url': 'https://api.github.com/users/montogeek/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/montogeek/received_events',
#    'type': 'User',
#    'site_admin': False,
#    'contributions': 11},
#   {'login': 'karllhughes',
#    'id': 1103622,
#    'node_id': 'MDQ6VXNlcjExMDM2MjI=',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/1103622?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/karllhughes',
#    'html_url': 'https://github.com/karllhughes',
#    'followers_url': 'https://api.github.com/users/karllhughes/followers',
#    'following_url': 'https://api.github.com/users/karllhughes/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/karllhughes/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/karllhughes/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/karllhughes/subscriptions',
#    'organizations_url': 'https://api.github.com/users/karllhughes/orgs',
#    'repos_url': 'https://api.github.com/users/karllhughes/repos',
#    'events_url': 'https://api.github.com/users/karllhughes/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/karllhughes/received_events',
#    'type': 'User',
#    'site_admin': False,
#    'contributions': 11},
#   {'login': 'hardikpthv',
#    'id': 9882972,
#    'node_id': 'MDQ6VXNlcjk4ODI5NzI=',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/9882972?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/hardikpthv',
#    'html_url': 'https://github.com/hardikpthv',
#    'followers_url': 'https://api.github.com/users/hardikpthv/followers',
#    'following_url': 'https://api.github.com/users/hardikpthv/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/hardikpthv/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/hardikpthv/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/hardikpthv/subscriptions',
#    'organizations_url': 'https://api.github.com/users/hardikpthv/orgs',
#    'repos_url': 'https://api.github.com/users/hardikpthv/repos',
#    'events_url': 'https://api.github.com/users/hardikpthv/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/hardikpthv/received_events',
#    'type': 'User',
#    'site_admin': False,
#    'contributions': 11},
#   {'login': 'awalthefirst',
#    'id': 11713455,
#    'node_id': 'MDQ6VXNlcjExNzEzNDU1',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/11713455?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/awalthefirst',
#    'html_url': 'https://github.com/awalthefirst',
#    'followers_url': 'https://api.github.com/users/awalthefirst/followers',
#    'following_url': 'https://api.github.com/users/awalthefirst/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/awalthefirst/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/awalthefirst/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/awalthefirst/subscriptions',
#    'organizations_url': 'https://api.github.com/users/awalthefirst/orgs',
#    'repos_url': 'https://api.github.com/users/awalthefirst/repos',
#    'events_url': 'https://api.github.com/users/awalthefirst/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/awalthefirst/received_events',
#    'type': 'User',
#    'site_admin': False,
#    'contributions': 9},
#   {'login': 'fawazahmed0',
#    'id': 20347013,
#    'node_id': 'MDQ6VXNlcjIwMzQ3MDEz',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/20347013?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/fawazahmed0',
#    'html_url': 'https://github.com/fawazahmed0',
#    'followers_url': 'https://api.github.com/users/fawazahmed0/followers',
#    'following_url': 'https://api.github.com/users/fawazahmed0/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/fawazahmed0/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/fawazahmed0/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/fawazahmed0/subscriptions',
#    'organizations_url': 'https://api.github.com/users/fawazahmed0/orgs',
#    'repos_url': 'https://api.github.com/users/fawazahmed0/repos',
#    'events_url': 'https://api.github.com/users/fawazahmed0/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/fawazahmed0/received_events',
#    'type': 'User',
#    'site_admin': False,
#    'contributions': 9},
#   {'login': 'kanaksony',
#    'id': 6097596,
#    'node_id': 'MDQ6VXNlcjYwOTc1OTY=',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/6097596?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/kanaksony',
#    'html_url': 'https://github.com/kanaksony',
#    'followers_url': 'https://api.github.com/users/kanaksony/followers',
#    'following_url': 'https://api.github.com/users/kanaksony/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/kanaksony/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/kanaksony/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/kanaksony/subscriptions',
#    'organizations_url': 'https://api.github.com/users/kanaksony/orgs',
#    'repos_url': 'https://api.github.com/users/kanaksony/repos',
#    'events_url': 'https://api.github.com/users/kanaksony/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/kanaksony/received_events',
#    'type': 'User',
#    'site_admin': False,
#    'contributions': 8},
#   {'login': 'codewithpom',
#    'id': 79435304,
#    'node_id': 'MDQ6VXNlcjc5NDM1MzA0',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/79435304?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/codewithpom',
#    'html_url': 'https://github.com/codewithpom',
#    'followers_url': 'https://api.github.com/users/codewithpom/followers',
#    'following_url': 'https://api.github.com/users/codewithpom/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/codewithpom/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/codewithpom/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/codewithpom/subscriptions',
#    'organizations_url': 'https://api.github.com/users/codewithpom/orgs',
#    'repos_url': 'https://api.github.com/users/codewithpom/repos',
#    'events_url': 'https://api.github.com/users/codewithpom/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/codewithpom/received_events',
#    'type': 'User',
#    'site_admin': False,
#    'contributions': 8},
#   {'login': 'sonali623',
#    'id': 44675394,
#    'node_id': 'MDQ6VXNlcjQ0Njc1Mzk0',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/44675394?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/sonali623',
#    'html_url': 'https://github.com/sonali623',
#    'followers_url': 'https://api.github.com/users/sonali623/followers',
#    'following_url': 'https://api.github.com/users/sonali623/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/sonali623/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/sonali623/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/sonali623/subscriptions',
#    'organizations_url': 'https://api.github.com/users/sonali623/orgs',
#    'repos_url': 'https://api.github.com/users/sonali623/repos',
#    'events_url': 'https://api.github.com/users/sonali623/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/sonali623/received_events',
#    'type': 'User',
#    'site_admin': False,
#    'contributions': 8},
#   {'login': 'molcik',
#    'id': 11929953,
#    'node_id': 'MDQ6VXNlcjExOTI5OTUz',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/11929953?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/molcik',
#    'html_url': 'https://github.com/molcik',
#    'followers_url': 'https://api.github.com/users/molcik/followers',
#    'following_url': 'https://api.github.com/users/molcik/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/molcik/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/molcik/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/molcik/subscriptions',
#    'organizations_url': 'https://api.github.com/users/molcik/orgs',
#    'repos_url': 'https://api.github.com/users/molcik/repos',
#    'events_url': 'https://api.github.com/users/molcik/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/molcik/received_events',
#    'type': 'User',
#    'site_admin': False,
#    'contributions': 7},
#   {'login': 'CipherGirl',
#    'id': 37832457,
#    'node_id': 'MDQ6VXNlcjM3ODMyNDU3',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/37832457?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/CipherGirl',
#    'html_url': 'https://github.com/CipherGirl',
#    'followers_url': 'https://api.github.com/users/CipherGirl/followers',
#    'following_url': 'https://api.github.com/users/CipherGirl/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/CipherGirl/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/CipherGirl/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/CipherGirl/subscriptions',
#    'organizations_url': 'https://api.github.com/users/CipherGirl/orgs',
#    'repos_url': 'https://api.github.com/users/CipherGirl/repos',
#    'events_url': 'https://api.github.com/users/CipherGirl/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/CipherGirl/received_events',
#    'type': 'User',
#    'site_admin': False,
#    'contributions': 7},
#   {'login': 'ChaseDurand',
#    'id': 50851884,
#    'node_id': 'MDQ6VXNlcjUwODUxODg0',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/50851884?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/ChaseDurand',
#    'html_url': 'https://github.com/ChaseDurand',
#    'followers_url': 'https://api.github.com/users/ChaseDurand/followers',
#    'following_url': 'https://api.github.com/users/ChaseDurand/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/ChaseDurand/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/ChaseDurand/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/ChaseDurand/subscriptions',
#    'organizations_url': 'https://api.github.com/users/ChaseDurand/orgs',
#    'repos_url': 'https://api.github.com/users/ChaseDurand/repos',
#    'events_url': 'https://api.github.com/users/ChaseDurand/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/ChaseDurand/received_events',
#    'type': 'User',
#    'site_admin': False,
#    'contributions': 7},
#   {'login': 'hippyaki',
#    'id': 52236719,
#    'node_id': 'MDQ6VXNlcjUyMjM2NzE5',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/52236719?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/hippyaki',
#    'html_url': 'https://github.com/hippyaki',
#    'followers_url': 'https://api.github.com/users/hippyaki/followers',
#    'following_url': 'https://api.github.com/users/hippyaki/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/hippyaki/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/hippyaki/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/hippyaki/subscriptions',
#    'organizations_url': 'https://api.github.com/users/hippyaki/orgs',
#    'repos_url': 'https://api.github.com/users/hippyaki/repos',
#    'events_url': 'https://api.github.com/users/hippyaki/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/hippyaki/received_events',
#    'type': 'User',
#    'site_admin': False,
#    'contributions': 7},
#   {'login': 'xnekv03',
#    'id': 17554971,
#    'node_id': 'MDQ6VXNlcjE3NTU0OTcx',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/17554971?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/xnekv03',
#    'html_url': 'https://github.com/xnekv03',
#    'followers_url': 'https://api.github.com/users/xnekv03/followers',
#    'following_url': 'https://api.github.com/users/xnekv03/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/xnekv03/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/xnekv03/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/xnekv03/subscriptions',
#    'organizations_url': 'https://api.github.com/users/xnekv03/orgs',
#    'repos_url': 'https://api.github.com/users/xnekv03/repos',
#    'events_url': 'https://api.github.com/users/xnekv03/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/xnekv03/received_events',
#    'type': 'User',
#    'site_admin': False,
#    'contributions': 6},
#   {'login': 'DylanDelobel',
#    'id': 5182186,
#    'node_id': 'MDQ6VXNlcjUxODIxODY=',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/5182186?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/DylanDelobel',
#    'html_url': 'https://github.com/DylanDelobel',
#    'followers_url': 'https://api.github.com/users/DylanDelobel/followers',
#    'following_url': 'https://api.github.com/users/DylanDelobel/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/DylanDelobel/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/DylanDelobel/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/DylanDelobel/subscriptions',
#    'organizations_url': 'https://api.github.com/users/DylanDelobel/orgs',
#    'repos_url': 'https://api.github.com/users/DylanDelobel/repos',
#    'events_url': 'https://api.github.com/users/DylanDelobel/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/DylanDelobel/received_events',
#    'type': 'User',
#    'site_admin': False,
#    'contributions': 6},
#   {'login': 'draco-malfoy',
#    'id': 46344490,
#    'node_id': 'MDQ6VXNlcjQ2MzQ0NDkw',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/46344490?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/draco-malfoy',
#    'html_url': 'https://github.com/draco-malfoy',
#    'followers_url': 'https://api.github.com/users/draco-malfoy/followers',
#    'following_url': 'https://api.github.com/users/draco-malfoy/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/draco-malfoy/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/draco-malfoy/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/draco-malfoy/subscriptions',
#    'organizations_url': 'https://api.github.com/users/draco-malfoy/orgs',
#    'repos_url': 'https://api.github.com/users/draco-malfoy/repos',
#    'events_url': 'https://api.github.com/users/draco-malfoy/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/draco-malfoy/received_events',
#    'type': 'User',
#    'site_admin': False,
#    'contributions': 6},
#   {'login': 'chief10',
#    'id': 2761499,
#    'node_id': 'MDQ6VXNlcjI3NjE0OTk=',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/2761499?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/chief10',
#    'html_url': 'https://github.com/chief10',
#    'followers_url': 'https://api.github.com/users/chief10/followers',
#    'following_url': 'https://api.github.com/users/chief10/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/chief10/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/chief10/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/chief10/subscriptions',
#    'organizations_url': 'https://api.github.com/users/chief10/orgs',
#    'repos_url': 'https://api.github.com/users/chief10/repos',
#    'events_url': 'https://api.github.com/users/chief10/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/chief10/received_events',
#    'type': 'User',
#    'site_admin': False,
#    'contributions': 6},
#   {'login': 'ca13ra1',
#    'id': 1849851,
#    'node_id': 'MDQ6VXNlcjE4NDk4NTE=',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/1849851?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/ca13ra1',
#    'html_url': 'https://github.com/ca13ra1',
#    'followers_url': 'https://api.github.com/users/ca13ra1/followers',
#    'following_url': 'https://api.github.com/users/ca13ra1/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/ca13ra1/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/ca13ra1/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/ca13ra1/subscriptions',
#    'organizations_url': 'https://api.github.com/users/ca13ra1/orgs',
#    'repos_url': 'https://api.github.com/users/ca13ra1/repos',
#    'events_url': 'https://api.github.com/users/ca13ra1/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/ca13ra1/received_events',
#    'type': 'User',
#    'site_admin': False,
#    'contributions': 6},
#   {'login': 'neosergio',
#    'id': 50982,
#    'node_id': 'MDQ6VXNlcjUwOTgy',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/50982?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/neosergio',
#    'html_url': 'https://github.com/neosergio',
#    'followers_url': 'https://api.github.com/users/neosergio/followers',
#    'following_url': 'https://api.github.com/users/neosergio/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/neosergio/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/neosergio/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/neosergio/subscriptions',
#    'organizations_url': 'https://api.github.com/users/neosergio/orgs',
#    'repos_url': 'https://api.github.com/users/neosergio/repos',
#    'events_url': 'https://api.github.com/users/neosergio/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/neosergio/received_events',
#    'type': 'User',
#    'site_admin': False,
#    'contributions': 6},
#   {'login': 'NaveenDA',
#    'id': 20555082,
#    'node_id': 'MDQ6VXNlcjIwNTU1MDgy',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/20555082?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/NaveenDA',
#    'html_url': 'https://github.com/NaveenDA',
#    'followers_url': 'https://api.github.com/users/NaveenDA/followers',
#    'following_url': 'https://api.github.com/users/NaveenDA/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/NaveenDA/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/NaveenDA/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/NaveenDA/subscriptions',
#    'organizations_url': 'https://api.github.com/users/NaveenDA/orgs',
#    'repos_url': 'https://api.github.com/users/NaveenDA/repos',
#    'events_url': 'https://api.github.com/users/NaveenDA/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/NaveenDA/received_events',
#    'type': 'User',
#    'site_admin': False,
#    'contributions': 6},
#   {'login': 'brakmic',
#    'id': 56779,
#    'node_id': 'MDQ6VXNlcjU2Nzc5',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/56779?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/brakmic',
#    'html_url': 'https://github.com/brakmic',
#    'followers_url': 'https://api.github.com/users/brakmic/followers',
#    'following_url': 'https://api.github.com/users/brakmic/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/brakmic/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/brakmic/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/brakmic/subscriptions',
#    'organizations_url': 'https://api.github.com/users/brakmic/orgs',
#    'repos_url': 'https://api.github.com/users/brakmic/repos',
#    'events_url': 'https://api.github.com/users/brakmic/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/brakmic/received_events',
#    'type': 'User',
#    'site_admin': False,
#    'contributions': 6},
#   {'login': 'alxpez',
#    'id': 5973189,
#    'node_id': 'MDQ6VXNlcjU5NzMxODk=',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/5973189?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/alxpez',
#    'html_url': 'https://github.com/alxpez',
#    'followers_url': 'https://api.github.com/users/alxpez/followers',
#    'following_url': 'https://api.github.com/users/alxpez/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/alxpez/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/alxpez/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/alxpez/subscriptions',
#    'organizations_url': 'https://api.github.com/users/alxpez/orgs',
#    'repos_url': 'https://api.github.com/users/alxpez/repos',
#    'events_url': 'https://api.github.com/users/alxpez/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/alxpez/received_events',
#    'type': 'User',
#    'site_admin': False,
#    'contributions': 6},
#   {'login': 'mic-rigaud',
#    'id': 19793123,
#    'node_id': 'MDQ6VXNlcjE5NzkzMTIz',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/19793123?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/mic-rigaud',
#    'html_url': 'https://github.com/mic-rigaud',
#    'followers_url': 'https://api.github.com/users/mic-rigaud/followers',
#    'following_url': 'https://api.github.com/users/mic-rigaud/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/mic-rigaud/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/mic-rigaud/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/mic-rigaud/subscriptions',
#    'organizations_url': 'https://api.github.com/users/mic-rigaud/orgs',
#    'repos_url': 'https://api.github.com/users/mic-rigaud/repos',
#    'events_url': 'https://api.github.com/users/mic-rigaud/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/mic-rigaud/received_events',
#    'type': 'User',
#    'site_admin': False,
#    'contributions': 5},
#   {'login': 'Morrolan',
#    'id': 180142,
#    'node_id': 'MDQ6VXNlcjE4MDE0Mg==',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/180142?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/Morrolan',
#    'html_url': 'https://github.com/Morrolan',
#    'followers_url': 'https://api.github.com/users/Morrolan/followers',
#    'following_url': 'https://api.github.com/users/Morrolan/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/Morrolan/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/Morrolan/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/Morrolan/subscriptions',
#    'organizations_url': 'https://api.github.com/users/Morrolan/orgs',
#    'repos_url': 'https://api.github.com/users/Morrolan/repos',
#    'events_url': 'https://api.github.com/users/Morrolan/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/Morrolan/received_events',
#    'type': 'User',
#    'site_admin': False,
#    'contributions': 5},
#   {'login': 'xinitrc-dev',
#    'id': 14354528,
#    'node_id': 'MDQ6VXNlcjE0MzU0NTI4',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/14354528?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/xinitrc-dev',
#    'html_url': 'https://github.com/xinitrc-dev',
#    'followers_url': 'https://api.github.com/users/xinitrc-dev/followers',
#    'following_url': 'https://api.github.com/users/xinitrc-dev/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/xinitrc-dev/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/xinitrc-dev/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/xinitrc-dev/subscriptions',
#    'organizations_url': 'https://api.github.com/users/xinitrc-dev/orgs',
#    'repos_url': 'https://api.github.com/users/xinitrc-dev/repos',
#    'events_url': 'https://api.github.com/users/xinitrc-dev/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/xinitrc-dev/received_events',
#    'type': 'User',
#    'site_admin': False,
#    'contributions': 5},
#   {'login': 'happiestbee',
#    'id': 87628038,
#    'node_id': 'MDQ6VXNlcjg3NjI4MDM4',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/87628038?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/happiestbee',
#    'html_url': 'https://github.com/happiestbee',
#    'followers_url': 'https://api.github.com/users/happiestbee/followers',
#    'following_url': 'https://api.github.com/users/happiestbee/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/happiestbee/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/happiestbee/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/happiestbee/subscriptions',
#    'organizations_url': 'https://api.github.com/users/happiestbee/orgs',
#    'repos_url': 'https://api.github.com/users/happiestbee/repos',
#    'events_url': 'https://api.github.com/users/happiestbee/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/happiestbee/received_events',
#    'type': 'User',
#    'site_admin': False,
#    'contributions': 5},
#   {'login': 'Satish-Prajapati',
#    'id': 25876221,
#    'node_id': 'MDQ6VXNlcjI1ODc2MjIx',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/25876221?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/Satish-Prajapati',
#    'html_url': 'https://github.com/Satish-Prajapati',
#    'followers_url': 'https://api.github.com/users/Satish-Prajapati/followers',
#    'following_url': 'https://api.github.com/users/Satish-Prajapati/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/Satish-Prajapati/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/Satish-Prajapati/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/Satish-Prajapati/subscriptions',
#    'organizations_url': 'https://api.github.com/users/Satish-Prajapati/orgs',
#    'repos_url': 'https://api.github.com/users/Satish-Prajapati/repos',
#    'events_url': 'https://api.github.com/users/Satish-Prajapati/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/Satish-Prajapati/received_events',
#    'type': 'User',
#    'site_admin': False,
#    'contributions': 5},
#   {'login': 'romellfudi',
#    'id': 1668017,
#    'node_id': 'MDQ6VXNlcjE2NjgwMTc=',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/1668017?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/romellfudi',
#    'html_url': 'https://github.com/romellfudi',
#    'followers_url': 'https://api.github.com/users/romellfudi/followers',
#    'following_url': 'https://api.github.com/users/romellfudi/following{/other_user}',
# ...
#    'events_url': 'https://api.github.com/users/irfan-dahir/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/irfan-dahir/received_events',
#    'type': 'User',
#    'site_admin': False,
#    'contributions': 4},
#   {'login': 'JaphethOlu',
#    'id': 20114946,
#    'node_id': 'MDQ6VXNlcjIwMTE0OTQ2',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/20114946?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/JaphethOlu',
#    'html_url': 'https://github.com/JaphethOlu',
#    'followers_url': 'https://api.github.com/users/JaphethOlu/followers',
#    'following_url': 'https://api.github.com/users/JaphethOlu/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/JaphethOlu/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/JaphethOlu/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/JaphethOlu/subscriptions',
#    'organizations_url': 'https://api.github.com/users/JaphethOlu/orgs',
#    'repos_url': 'https://api.github.com/users/JaphethOlu/repos',
#    'events_url': 'https://api.github.com/users/JaphethOlu/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/JaphethOlu/received_events',
#    'type': 'User',
#    'site_admin': False,
#    'contributions': 4},
#   {'login': 'sakulich',
#    'id': 16674690,
#    'node_id': 'MDQ6VXNlcjE2Njc0Njkw',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/16674690?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/sakulich',
#    'html_url': 'https://github.com/sakulich',
#    'followers_url': 'https://api.github.com/users/sakulich/followers',
#    'following_url': 'https://api.github.com/users/sakulich/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/sakulich/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/sakulich/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/sakulich/subscriptions',
#    'organizations_url': 'https://api.github.com/users/sakulich/orgs',
#    'repos_url': 'https://api.github.com/users/sakulich/repos',
#    'events_url': 'https://api.github.com/users/sakulich/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/sakulich/received_events',
#    'type': 'User',
#    'site_admin': False,
#    'contributions': 4},
#   {'login': 'samanyougarg',
#    'id': 32533774,
#    'node_id': 'MDQ6VXNlcjMyNTMzNzc0',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/32533774?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/samanyougarg',
#    'html_url': 'https://github.com/samanyougarg',
#    'followers_url': 'https://api.github.com/users/samanyougarg/followers',
#    'following_url': 'https://api.github.com/users/samanyougarg/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/samanyougarg/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/samanyougarg/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/samanyougarg/subscriptions',
#    'organizations_url': 'https://api.github.com/users/samanyougarg/orgs',
#    'repos_url': 'https://api.github.com/users/samanyougarg/repos',
#    'events_url': 'https://api.github.com/users/samanyougarg/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/samanyougarg/received_events',
#    'type': 'User',
#    'site_admin': False,
#    'contributions': 4},
#   {'login': 'distributedlock',
#    'id': 7084995,
#    'node_id': 'MDQ6VXNlcjcwODQ5OTU=',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/7084995?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/distributedlock',
#    'html_url': 'https://github.com/distributedlock',
#    'followers_url': 'https://api.github.com/users/distributedlock/followers',
#    'following_url': 'https://api.github.com/users/distributedlock/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/distributedlock/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/distributedlock/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/distributedlock/subscriptions',
#    'organizations_url': 'https://api.github.com/users/distributedlock/orgs',
#    'repos_url': 'https://api.github.com/users/distributedlock/repos',
#    'events_url': 'https://api.github.com/users/distributedlock/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/distributedlock/received_events',
#    'type': 'User',
#    'site_admin': False,
#    'contributions': 4},
#   {'login': 'vahgar',
#    'id': 13184683,
#    'node_id': 'MDQ6VXNlcjEzMTg0Njgz',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/13184683?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/vahgar',
#    'html_url': 'https://github.com/vahgar',
#    'followers_url': 'https://api.github.com/users/vahgar/followers',
#    'following_url': 'https://api.github.com/users/vahgar/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/vahgar/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/vahgar/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/vahgar/subscriptions',
#    'organizations_url': 'https://api.github.com/users/vahgar/orgs',
#    'repos_url': 'https://api.github.com/users/vahgar/repos',
#    'events_url': 'https://api.github.com/users/vahgar/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/vahgar/received_events',
#    'type': 'User',
#    'site_admin': False,
#    'contributions': 4},
#   {'login': 'paramt',
#    'id': 23563074,
#    'node_id': 'MDQ6VXNlcjIzNTYzMDc0',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/23563074?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/paramt',
#    'html_url': 'https://github.com/paramt',
#    'followers_url': 'https://api.github.com/users/paramt/followers',
#    'following_url': 'https://api.github.com/users/paramt/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/paramt/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/paramt/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/paramt/subscriptions',
#    'organizations_url': 'https://api.github.com/users/paramt/orgs',
#    'repos_url': 'https://api.github.com/users/paramt/repos',
#    'events_url': 'https://api.github.com/users/paramt/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/paramt/received_events',
#    'type': 'User',
#    'site_admin': False,
#    'contributions': 4},
#   {'login': 'mykolasolodukha',
#    'id': 39992593,
#    'node_id': 'MDQ6VXNlcjM5OTkyNTkz',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/39992593?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/mykolasolodukha',
#    'html_url': 'https://github.com/mykolasolodukha',
#    'followers_url': 'https://api.github.com/users/mykolasolodukha/followers',
#    'following_url': 'https://api.github.com/users/mykolasolodukha/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/mykolasolodukha/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/mykolasolodukha/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/mykolasolodukha/subscriptions',
#    'organizations_url': 'https://api.github.com/users/mykolasolodukha/orgs',
#    'repos_url': 'https://api.github.com/users/mykolasolodukha/repos',
#    'events_url': 'https://api.github.com/users/mykolasolodukha/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/mykolasolodukha/received_events',
#    'type': 'User',
#    'site_admin': False,
#    'contributions': 4},
#   {'login': 'kamikazechaser',
#    'id': 18488025,
#    'node_id': 'MDQ6VXNlcjE4NDg4MDI1',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/18488025?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/kamikazechaser',
#    'html_url': 'https://github.com/kamikazechaser',
#    'followers_url': 'https://api.github.com/users/kamikazechaser/followers',
#    'following_url': 'https://api.github.com/users/kamikazechaser/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/kamikazechaser/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/kamikazechaser/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/kamikazechaser/subscriptions',
#    'organizations_url': 'https://api.github.com/users/kamikazechaser/orgs',
#    'repos_url': 'https://api.github.com/users/kamikazechaser/repos',
#    'events_url': 'https://api.github.com/users/kamikazechaser/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/kamikazechaser/received_events',
#    'type': 'User',
#    'site_admin': False,
#    'contributions': 4},
#   {'login': 'MedUnes',
#    'id': 8580094,
#    'node_id': 'MDQ6VXNlcjg1ODAwOTQ=',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/8580094?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/MedUnes',
#    'html_url': 'https://github.com/MedUnes',
#    'followers_url': 'https://api.github.com/users/MedUnes/followers',
#    'following_url': 'https://api.github.com/users/MedUnes/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/MedUnes/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/MedUnes/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/MedUnes/subscriptions',
#    'organizations_url': 'https://api.github.com/users/MedUnes/orgs',
#    'repos_url': 'https://api.github.com/users/MedUnes/repos',
#    'events_url': 'https://api.github.com/users/MedUnes/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/MedUnes/received_events',
#    'type': 'User',
#    'site_admin': False,
#    'contributions': 4},
#   {'login': 'mjarkk',
#    'id': 15320763,
#    'node_id': 'MDQ6VXNlcjE1MzIwNzYz',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/15320763?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/mjarkk',
#    'html_url': 'https://github.com/mjarkk',
#    'followers_url': 'https://api.github.com/users/mjarkk/followers',
#    'following_url': 'https://api.github.com/users/mjarkk/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/mjarkk/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/mjarkk/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/mjarkk/subscriptions',
#    'organizations_url': 'https://api.github.com/users/mjarkk/orgs',
#    'repos_url': 'https://api.github.com/users/mjarkk/repos',
#    'events_url': 'https://api.github.com/users/mjarkk/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/mjarkk/received_events',
#    'type': 'User',
#    'site_admin': False,
#    'contributions': 4},
#   {'login': 'marcobiedermann',
#    'id': 5244986,
#    'node_id': 'MDQ6VXNlcjUyNDQ5ODY=',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/5244986?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/marcobiedermann',
#    'html_url': 'https://github.com/marcobiedermann',
#    'followers_url': 'https://api.github.com/users/marcobiedermann/followers',
#    'following_url': 'https://api.github.com/users/marcobiedermann/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/marcobiedermann/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/marcobiedermann/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/marcobiedermann/subscriptions',
#    'organizations_url': 'https://api.github.com/users/marcobiedermann/orgs',
#    'repos_url': 'https://api.github.com/users/marcobiedermann/repos',
#    'events_url': 'https://api.github.com/users/marcobiedermann/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/marcobiedermann/received_events',
#    'type': 'User',
#    'site_admin': False,
#    'contributions': 4},
#   {'login': 'CeruttiMaicon',
#    'id': 25940408,
#    'node_id': 'MDQ6VXNlcjI1OTQwNDA4',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/25940408?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/CeruttiMaicon',
#    'html_url': 'https://github.com/CeruttiMaicon',
#    'followers_url': 'https://api.github.com/users/CeruttiMaicon/followers',
#    'following_url': 'https://api.github.com/users/CeruttiMaicon/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/CeruttiMaicon/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/CeruttiMaicon/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/CeruttiMaicon/subscriptions',
#    'organizations_url': 'https://api.github.com/users/CeruttiMaicon/orgs',
#    'repos_url': 'https://api.github.com/users/CeruttiMaicon/repos',
#    'events_url': 'https://api.github.com/users/CeruttiMaicon/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/CeruttiMaicon/received_events',
#    'type': 'User',
#    'site_admin': False,
#    'contributions': 4},
#   {'login': 'ldobreira',
#    'id': 64305063,
#    'node_id': 'MDQ6VXNlcjY0MzA1MDYz',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/64305063?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/ldobreira',
#    'html_url': 'https://github.com/ldobreira',
#    'followers_url': 'https://api.github.com/users/ldobreira/followers',
#    'following_url': 'https://api.github.com/users/ldobreira/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/ldobreira/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/ldobreira/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/ldobreira/subscriptions',
#    'organizations_url': 'https://api.github.com/users/ldobreira/orgs',
#    'repos_url': 'https://api.github.com/users/ldobreira/repos',
#    'events_url': 'https://api.github.com/users/ldobreira/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/ldobreira/received_events',
#    'type': 'User',
#    'site_admin': False,
#    'contributions': 4},
#   {'login': 'LordGhostX',
#    'id': 47832826,
#    'node_id': 'MDQ6VXNlcjQ3ODMyODI2',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/47832826?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/LordGhostX',
#    'html_url': 'https://github.com/LordGhostX',
#    'followers_url': 'https://api.github.com/users/LordGhostX/followers',
#    'following_url': 'https://api.github.com/users/LordGhostX/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/LordGhostX/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/LordGhostX/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/LordGhostX/subscriptions',
#    'organizations_url': 'https://api.github.com/users/LordGhostX/orgs',
#    'repos_url': 'https://api.github.com/users/LordGhostX/repos',
#    'events_url': 'https://api.github.com/users/LordGhostX/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/LordGhostX/received_events',
#    'type': 'User',
#    'site_admin': False,
#    'contributions': 4},
#   {'login': 'Kikobeats',
#    'id': 2096101,
#    'node_id': 'MDQ6VXNlcjIwOTYxMDE=',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/2096101?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/Kikobeats',
#    'html_url': 'https://github.com/Kikobeats',
#    'followers_url': 'https://api.github.com/users/Kikobeats/followers',
#    'following_url': 'https://api.github.com/users/Kikobeats/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/Kikobeats/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/Kikobeats/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/Kikobeats/subscriptions',
#    'organizations_url': 'https://api.github.com/users/Kikobeats/orgs',
#    'repos_url': 'https://api.github.com/users/Kikobeats/repos',
#    'events_url': 'https://api.github.com/users/Kikobeats/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/Kikobeats/received_events',
#    'type': 'User',
#    'site_admin': False,
#    'contributions': 4}]}

# %%
sizes = np.array([repo["size"] for repo in repos])
stargazers = np.array([repo["stargazers_count"] for repo in repos])
watchers = np.array([repo["watchers_count"] for repo in repos])
forks = np.array([repo["forks_count"] for repo in repos])
open_issues = np.array([repo["open_issues_count"] for repo in repos])
contributors = np.array([len(repo["total_contributors"]) for repo in repos])
contributions = np.array([sum([c["contributions"] for c in repo["total_contributors"]]) for repo in repos])
scores = np.array([repo["score"] for repo in repos])

df = pd.DataFrame({
    "size": sizes,
    "stargazers": stargazers,
    "watchers": watchers,
    "forks": forks,
    "open_issues": open_issues,
    "contributors": contributors,
    "contributions": contributions
})

df.head()
# Out:
#      size  stargazers  watchers  forks  open_issues  contributors  \
# 0    4997      293444    293444  31931          261           100
# 1   11187      257108    257108  43831          425           100
# 2    6789      206774    206774  24510          416           100
# 3   15030      180379    180379  43750          247           100
# 4  330701      150547    150547  51395          715            12
#
#    contributions
# 0           2825
# 1            299
# 2           1276
# 3           1745
# 4            374

# %%
log_df = df.copy()
log_df["size"] = np.log10(df["size"])
log_df["watchers"] = np.log10(df["watchers"])
log_df["forks"] = np.log10(df["forks"])
log_df["open_issues"] = np.log10(df["open_issues"])
log_df["contributors"] = df["contributors"]
log_df["contributions"] = np.log10(df["contributions"])

log_df.replace(-np.inf, 0, inplace=True)


fig, axs = plt.subplots(3, 2)
fig.set_size_inches(10, 20)

sns.kdeplot(data=log_df, x="size", ax=axs[0, 0])
axs[0, 0].set_xlabel("log(size)")
sns.kdeplot(data=log_df, x="watchers", ax=axs[1, 0])
axs[1, 0].set_xlabel("log(watchers)")
sns.kdeplot(data=log_df, x="forks", ax=axs[2, 0])
axs[2, 0].set_xlabel("log(forks)")
sns.kdeplot(data=log_df, x="open_issues", ax=axs[0, 1])
axs[0, 1].set_xlabel("log(open_issues)")
sns.kdeplot(data=log_df, x="contributors", ax=axs[1, 1])
sns.kdeplot(data=log_df, x="contributions", ax=axs[2, 1])
axs[2, 1].set_xlabel("log(contributions)")

axs[0, 0].set_ylabel("")
axs[1, 0].set_ylabel("")
axs[2, 0].set_ylabel("")
axs[0, 1].set_ylabel("")
axs[1, 1].set_ylabel("")
axs[2, 1].set_ylabel("")
# Out:
# /home/cr/Documents/hpi/out-of-date-docstrings/github-scraper/.venv/lib/python3.10/site-packages/pandas/core/arraylike.py:399: RuntimeWarning:
#
# divide by zero encountered in log10
# Text(0, 0.5, '')

# %%
norm_df = log_df.copy()
norm_df = (norm_df - norm_df.mean()) / norm_df.std()

fig, axs = plt.subplots(3, 2)
fig.set_size_inches(16, 24)

tsne = TSNE(n_components=2, perplexity=30.0, early_exaggeration=3.0, init='pca', method='barnes_hut')
tsne_result = tsne.fit_transform(norm_df)
tsne_df = pd.DataFrame(tsne_result, columns=["tsne1", "tsne2"])

tsne_df['size'] = log_df['size']
tsne_fig = sns.scatterplot(tsne_df, x='tsne1', y='tsne2', hue='size', palette='inferno', ax=axs[0, 0])
tsne_fig.set_xlabel("")
tsne_fig.set_ylabel("")
tsne_fig.legend(title="log(size)")
tsne_fig.set_xticks([])
tsne_fig.set_yticks([])
tsne_df.drop('size', axis=1, inplace=True)

tsne_df['watchers'] = log_df['watchers']
tsne_fig = sns.scatterplot(tsne_df, x='tsne1', y='tsne2', hue='watchers', palette='inferno', ax=axs[1, 0])
tsne_fig.set_xlabel("")
tsne_fig.set_ylabel("")
tsne_fig.legend(title="log(watchers)")
tsne_fig.set_xticks([])
tsne_fig.set_yticks([])
tsne_df.drop('watchers', axis=1, inplace=True)

tsne_df['forks'] = log_df['forks']
tsne_fig = sns.scatterplot(tsne_df, x='tsne1', y='tsne2', hue='forks', palette='inferno', ax=axs[2, 0])
tsne_fig.set_xlabel("")
tsne_fig.set_ylabel("")
tsne_fig.legend(title="log(forks)")
tsne_fig.set_xticks([])
tsne_fig.set_yticks([])
tsne_df.drop('forks', axis=1, inplace=True)

tsne_df['open_issues'] = log_df['open_issues']
tsne_fig = sns.scatterplot(tsne_df, x='tsne1', y='tsne2', hue='open_issues', palette='inferno', ax=axs[0, 1])
tsne_fig.set_xlabel("")
tsne_fig.set_ylabel("")
tsne_fig.legend(title="log(open_issues)")
tsne_fig.set_xticks([])
tsne_fig.set_yticks([])
tsne_df.drop('open_issues', axis=1, inplace=True)

tsne_df['contributors'] = log_df['contributors']
tsne_fig = sns.scatterplot(tsne_df, x='tsne1', y='tsne2', hue='contributors', palette='inferno', ax=axs[1, 1])
tsne_fig.set_xlabel("")
tsne_fig.set_ylabel("")
tsne_fig.set_xticks([])
tsne_fig.set_yticks([])
tsne_df.drop('contributors', axis=1, inplace=True)

tsne_df['contributions'] = log_df['contributions']
tsne_fig = sns.scatterplot(tsne_df, x='tsne1', y='tsne2', hue='contributions', palette='inferno', ax=axs[2, 1])
tsne_fig.set_xlabel("")
tsne_fig.set_ylabel("")
tsne_fig.legend(title="log(contributions)")
tsne_fig.set_xticks([])
tsne_fig.set_yticks([])
tsne_df.drop('contributions', axis=1, inplace=True)
